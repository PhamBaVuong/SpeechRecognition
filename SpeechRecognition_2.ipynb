# %% [markdown]
# <a href="https://colab.research.google.com/github/PhamBaVuong/SpeechRecognition/blob/main/SpeechRecognition_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Plot audio

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import wave
import matplotlib.pyplot as plt
import numpy as np

# %%
obj = wave.open('/content/drive/MyDrive/SpeechRecognition/01-basics_output.wav', 'rb')

# %%
sample_freq = obj.getframerate()
n_sample = obj.getnframes()
signal_wave = obj.readframes(-1)

obj.close()

# %%
t_audio = n_sample / sample_freq
print(t_audio)
# Out:
# 5.0

# %%
signal_array = np.frombuffer(signal_wave, dtype=np.int16)

times = np.linspace(0, t_audio, num=n_sample)

# %%
plt.figure(figsize=(15, 5))
plt.plot(times, signal_array)
plt.title('Audio Signal')
plt.ylabel('Signal wave')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()
